# %% [markdown]
# # Introduction
#
# This notebook retrieves and analyzes **Russian court cases** (criminal and administrative) from the **sudrf.ru** court information system. It uses the open-source `sudrfparser` project to:
#
# * automatically open court websites,
# * navigate their “Sudebnoe delo” module,
# * bypass captchas (optionally via 2Captcha),
# * download case metadata and full texts,
# * save results as structured JSON files.

# %% [markdown]
# ## Install a ChromeDriver Version That Matches Your Chrome Browser
#
# Before running the parser, you must install a ChromeDriver version that matches the version of Google Chrome installed on your computer.
# Chrome and ChromeDriver must be **exactly the same major version** (e.g., Chrome 142 → ChromeDriver 142).
# If they don’t match, Selenium will fail with an error like:
#
# > This version of ChromeDriver only supports Chrome version XXX.
# > Current browser version is YYY.

# %% [markdown]
# Installing dependencies matching versions expected by the parser:

# %%
# !pip install --upgrade beautifulsoup4 requests 2captcha-python webdriver_manager "selenium<4.0.0" "urllib3<2.0.0"
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (4.14.3)
# Requirement already satisfied: requests in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: 2captcha-python in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: webdriver_manager in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (4.0.2)
# Requirement already satisfied: selenium<4.0.0 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (3.141.0)
# Requirement already satisfied: urllib3<2.0.0 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (1.26.20)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: httpx in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from 2captcha-python) (0.28.1)
# Requirement already satisfied: aiofiles in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from 2captcha-python) (25.1.0)
# Requirement already satisfied: python-dotenv in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from webdriver_manager) (1.2.1)
# Requirement already satisfied: packaging in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from webdriver_manager) (25.0)
# Requirement already satisfied: anyio in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from httpx->2captcha-python) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from httpx->2captcha-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ana/Projects/soas/russian courts/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->2captcha-python) (0.16.0)

# %% [markdown]
# Clone the parser repo if you have not before

# %%
# !git clone https://github.com/dataout-org/sudrfparser.git

# %%
import sys
from pathlib import Path
import inspect

# Notebook directory: .../sudrfparser/example
nb_dir = Path.cwd()

# Project root is two levels above
project_root = nb_dir.parent.parent
print("Detected project root:", project_root)

# Add project root to sys.path so Python can find sudrfparser/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Now import the module
import sudrfparser.sudrfparser as sp

print("Loaded sudrfparser from:", sp.__file__)
print(
    "get_* functions:",
    [name for name, obj in inspect.getmembers(sp)
     if inspect.isfunction(obj) and name.startswith("get_")]
)
# Out:
# Detected project root: /Users/ana/Projects/soas/russian courts
# Loaded sudrfparser from: /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py
# get_* functions: ['get_adm_cases', 'get_cases', 'get_courts_list']
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:207: SyntaxWarning: invalid escape sequence '\d'
#   num_cases = int(re.search('\d+\.',num_cases_str)[0].rstrip("."))
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:234: SyntaxWarning: invalid escape sequence '\d'
#   case_id_str = re.search('case_id=\d*&case_uid=.*&',case_link)[0].rstrip('&')
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:373: SyntaxWarning: invalid escape sequence '\d'
#   if len(captcha_guessed) != 5 or re.search('\d{5}',captcha_guessed) == None:
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:625: SyntaxWarning: invalid escape sequence '\d'
#   num_cases = int(re.search('найдено - \d*',num_cases_str)[0].split('- ')[1])
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:628: SyntaxWarning: invalid escape sequence '\d'
#   pages_range = int(re.search('с \d по \d*',num_cases_str)[0].split(' ')[-1])
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:652: SyntaxWarning: invalid escape sequence '\d'
#   case_id = re.search('_id=\d*&_uid=.+?&',case_link)[0].rstrip('&')
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:779: SyntaxWarning: invalid escape sequence '\d'
#   if len(captcha_guessed) != 5 or re.search('\d{5}',captcha_guessed) == None:
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:2017: SyntaxWarning: invalid escape sequence '\d'
#   srv_num_str = re.search('(_\d)',court_str_id)[0]
# /Users/ana/Projects/soas/russian courts/sudrfparser/sudrfparser.py:2038: SyntaxWarning: invalid escape sequence '\d'
#   srv_num_str = "srv_" + re.search('(_\d*_)',file_path)[0].replace('_','')

# %% [markdown]
# Here you can specify the website and region and some other filters, as well as TwoCaptcha details if you are using it

# %% [markdown]
# Gathering administrative cases for the parameters provided. Adjust the path to your driver here if it is different.

# %%
# MASTER CELL: scrape all courts from sudrf_websites.json, saving per-court results

import os
import json
from pathlib import Path

# -------------------------------------------------------------------
# 0) Make sure we have a parser instance `sp`
# -------------------------------------------------------------------
try:
    sp  # type: ignore[name-defined]
except NameError:
    # adjust if your class / import is different
    from sudrfparser import SudRFParser
    sp = SudRFParser()

# -------------------------------------------------------------------
# 1) Global config
# -------------------------------------------------------------------

# Administrative articles: "<article>_<part>"
adm_articles = ["6.21_1", "6.21_2", "6.21_3", "6.21_4", "6.21_5", "6.21_6", "6.21_7", "6.21_8"]
ukr = ["282_2"]

# Date range (inclusive) in DD.MM.YYYY
start_date = "01.01.2021"
end_date   = "31.12.2025"

# Where to save all results
base_path_to_save = nb_dir.parent.parent / "sudrf_results_run_18.12_6_21"
base_path_to_save.mkdir(exist_ok=True)

# TwoCaptcha config (if you don't want auto-captcha, set captcha_config = {})
captcha_config = {
    "config": {"apiKey": "8ba2a5e6703e4c4769e8ced5f6976ccf"},  # put your real key here
    "numeric": 1,
    "minLen": 5,
    "maxLen": 5,
    "phrase": 0,
}

# Chromedriver path
path_to_driver = "/opt/homebrew/bin/chromedriver"

# Optional: limit to specific regions (e.g. {"78"}) or set None to process all
regions_whitelist = None  # e.g. {"78"} to only process St. Petersburg courts

# -------------------------------------------------------------------
# 2) Load courts list from sudrf_websites.json
# -------------------------------------------------------------------
courts_json_path = project_root / "sudrfparser" / "courts_info" / "sudrf_websites.json"
with courts_json_path.open("r", encoding="utf-8") as f:
    courts_by_region = json.load(f)

print("Base output directory:", base_path_to_save)
print("This run will save EACH court's summary separately and skip finished courts.\n")

# -------------------------------------------------------------------
# 3) Main loop: process court-by-court, saving immediately
# -------------------------------------------------------------------
for region_code, courts in courts_by_region.items():
    if regions_whitelist is not None and region_code not in regions_whitelist:
        continue

    print(f"\n=== Region {region_code} ===")

    for court in courts:
        court_id   = court["court_id"]
        court_name = court["court_name"]
        website    = court["court_website"]
        srv_nums   = court.get("srv", ["1"])

        # Folder for this court
        court_save_dir = base_path_to_save / region_code / court_id
        court_save_dir.mkdir(parents=True, exist_ok=True)

        summary_file = court_save_dir / "court_summary.json"
        error_file   = court_save_dir / "error.json"

        # Skip if already successfully processed
        if summary_file.exists():
            print(f"  -> SKIP {court_id} (summary exists)")
            continue

        print(f"  -> Processing {court_id}: {court_name}")
        print(f"     website={website}, srv={srv_nums}")

        try:
            result = sp.get_adm_cases(
                website=website,
                region=region_code,
                adm_articles=adm_articles,
                start_date=start_date,
                end_date=end_date,
                path_to_driver=path_to_driver,
                court_code=court_id,            # required for form2; ok for form1
                srv_num=srv_nums,               # e.g. ["1"] or ["1", "2"]
                path_to_save=str(court_save_dir) + os.sep,
                captcha_config=captcha_config,
            )

            # result = sp.get_cases(
            #     website=website,
            #     region=region_code,
            #     adm_articles=adm_articles,
            #     start_date=start_date,
            #     end_date=end_date,
            #     path_to_driver=path_to_driver,
            #     court_code=court_id,            # required for form2; ok for form1
            #     srv_num=srv_nums,               # e.g. ["1"] or ["1", "2"]
            #     path_to_save=str(court_save_dir) + os.sep,
            #     captcha_config=captcha_config,
            # )

            # Save per-court summary immediately
            with summary_file.open("w", encoding="utf-8") as f:
                json.dump(result, f, ensure_ascii=False, indent=2)

            # If there was an old error file from previous runs, you can optionally remove it
            if error_file.exists():
                error_file.unlink()

            print(f"     ✔ Saved summary → {summary_file}")

        except Exception as e:
            print(f"     ✖ ERROR for {court_id}: {e}")

            # Save error info for this court so we know it failed
            with error_file.open("w", encoding="utf-8") as f:
                json.dump({"error": str(e)}, f, ensure_ascii=False, indent=2)

            print(f"     ✔ Saved error log → {error_file}")
            # continue to next court

print("\n✅ Done. You can inspect per-court folders under:", base_path_to_save)
# Out:
# Base output directory: /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21
# This run will save EACH court's summary separately and skip finished courts.
#
#
# === Region 22 ===
#   -> Processing 22RS0001: Алейский городской суд (Алтайский край)
#      website=http://aleysky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0001/court_summary.json
#   -> Processing 22OS0000: Алтайский краевой суд (Алтайский край)
#      website=http://kraevoy.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22OS0000/court_summary.json
#   -> Processing 22RS0002: Алтайский районный суд (Алтайский край)
#      website=http://altaisky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0002/court_summary.json
#   -> Processing 22RS0070: Баевский районный суд (Алтайский край)
#      website=http://baevsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0070/court_summary.json
#   -> Processing 54GV0003: Барнаульский гарнизонный военный суд (Алтайский край)
#      website=http://bgvs.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/54GV0003/court_summary.json
#   -> Processing 22RS0007: Белокурихинский городской суд (Алтайский край)
#      website=http://belokurihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0007/court_summary.json
#   -> Processing 22RS0013: Бийский городской суд (Алтайский край)
#      website=http://biyskygor.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0013/court_summary.json
#   -> Processing 22RS0003: Бийский районный суд (Алтайский край)
#      website=http://biysky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0003/court_summary.json
#   -> Processing 22RS0004: Благовещенский районный суд (Алтайский край)
#      website=http://blagovechensky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0004/court_summary.json
#   -> Processing 22RS0005: Бурлинский районный суд (Алтайский край)
#      website=http://burlinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0005/court_summary.json
#   -> Processing 22RS0006: Быстроистокский районный суд (Алтайский край)
#      website=http://istoksky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0006/court_summary.json
#   -> Processing 22RS0016: Волчихинский районный суд (Алтайский край)
#      website=http://volchihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0016/court_summary.json
#   -> Processing 22RS0017: Егорьевский районный суд (Алтайский край)
#      website=http://egorevsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0017/court_summary.json
#   -> Processing 22RS0066: Железнодорожный районный суд г. Барнаула (Алтайский край)
#      website=http://zheleznodorozhny.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0066/court_summary.json
#   -> Processing 22RS0019: Завьяловский районный суд (Алтайский край)
#      website=http://zavialovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0019/court_summary.json
#   -> Processing 22RS0020: Залесовский районный суд (Алтайский край)
#      website=http://zalesovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0020/court_summary.json
#   -> Processing 22RS0008: Заринский городской суд (Алтайский край)
#      website=http://zarynsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0008/court_summary.json
#   -> Processing 22RS0021: Заринский районный суд (Алтайский край)
#      website=http://zarinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0021/court_summary.json
#   -> Processing 22RS0009: Змеиногорский городской суд (Алтайский край)
#      website=http://zmeinogorsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0009/court_summary.json
#   -> Processing 22RS0022: Зональный районный суд (Алтайский край)
#      website=http://zonalny.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0022/court_summary.json
#   -> Processing 22RS0065: Индустриальный районный суд г. Барнаула (Алтайский край)
#      website=http://industrialny.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0065/court_summary.json
#   -> Processing 22RS0023: Калманский районный суд (Алтайский край)
#      website=http://kalmansky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0023/court_summary.json
#   -> Processing 22RS0010: Каменский городской суд (Алтайский край)
#      website=http://kamensky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0010/court_summary.json
#   -> Processing 22RS0024: Ключевский районный суд (Алтайский край)
#      website=http://kluchevsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0024/court_summary.json
#   -> Processing 22RS0025: Косихинский районный суд (Алтайский край)
#      website=http://kosihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0025/court_summary.json
#   -> Processing 22RS0026: Красногорский районный суд (Алтайский край)
#      website=http://krasnogorsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0026/court_summary.json
#   -> Processing 22RS0027: Краснощековский районный суд (Алтайский край)
#      website=http://krasnochekovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0027/court_summary.json
#   -> Processing 22RS0028: Крутихинский районный суд (Алтайский край)
#      website=http://krutihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0028/court_summary.json
#   -> Processing 22RS0029: Кулундинский районный суд (Алтайский край)
#      website=http://kulundinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0029/court_summary.json
#   -> Processing 22RS0030: Курьинский районный суд (Алтайский край)
#      website=http://kyrinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0030/court_summary.json
#   -> Processing 22RS0031: Кытмановский районный суд (Алтайский край)
#      website=http://kytmanovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0031/court_summary.json
#   -> Processing 22RS0069: Ленинский районный суд г. Барнаула (Алтайский край)
#      website=http://leninsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0069/court_summary.json
#   -> Processing 22RS0032: Локтевский районный суд (Алтайский край)
#      website=http://loktevsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0032/court_summary.json
#   -> Processing 22RS0033: Мамонтовский районный суд (Алтайский край)
#      website=http://mamontovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0033/court_summary.json
#   -> Processing 22RS0034: Михайловский районный суд (Алтайский край)
#      website=http://mihalovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0034/court_summary.json
#   -> Processing 22RS0036: Новичихинский районный суд (Алтайский край)
#      website=http://novochihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0036/court_summary.json
#   -> Processing 22RS0015: Новоалтайский городской суд (Алтайский край)
#      website=http://novaltaisky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0015/court_summary.json
#   -> Processing 22RS0067: Октябрьский районный суд г. Барнаула (Алтайский край)
#      website=http://oktabrsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0067/court_summary.json
#   -> Processing 22RS0037: Павловский районный суд (Алтайский край)
#      website=http://pavlovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0037/court_summary.json
#   -> Processing 22RS0038: Панкрушихинский районный суд (Алтайский край)
#      website=http://pankrushihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0038/court_summary.json
#   -> Processing 22RS0039: Петропавловский районный суд (Алтайский край)
#      website=http://petropavlovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0039/court_summary.json
#   -> Processing 22RS0040: Поспелихинский районный суд (Алтайский край)
#      website=http://pospelihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0040/court_summary.json
#   -> Processing 22RS0035: Районный суд Немецкого национального района (Алтайский край)
#      website=http://nemecky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0035/court_summary.json
#   -> Processing 22RS0041: Ребрихинский районный суд (Алтайский край)
#      website=http://rebrihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0041/court_summary.json
#   -> Processing 22RS0042: Родинский районный суд (Алтайский край)
#      website=http://rodinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0042/court_summary.json
#   -> Processing 22RS0043: Романовский районный суд (Алтайский край)
#      website=http://romanovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0043/court_summary.json
#   -> Processing 22RS0011: Рубцовский городской суд (Алтайский край)
#      website=http://rubtcovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0011/court_summary.json
#   -> Processing 22RS0044: Рубцовский районный суд (Алтайский край)
#      website=http://rubcovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0044/court_summary.json
#   -> Processing 22RS0012: Славгородский городской суд (Алтайский край)
#      website=http://slavgorodsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0012/court_summary.json
#   -> Processing 22RS0045: Смоленский районный суд (Алтайский край)
#      website=http://smolensky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0045/court_summary.json
#   -> Processing 22RS0046: Советский районный суд (Алтайский край)
#      website=http://sovetsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0046/court_summary.json
#   -> Processing 22RS0047: Солонешенский районный суд (Алтайский край)
#      website=http://soloneshensky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0047/court_summary.json
#   -> Processing 22RS0048: Солтонский районный суд (Алтайский край)
#      website=http://soltonsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0048/court_summary.json
#   -> Processing 22RS0050: Табунский районный суд (Алтайский край)
#      website=http://tabunsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0050/court_summary.json
#   -> Processing 22RS0051: Тальменский районный суд (Алтайский край)
#      website=http://talmensky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0051/court_summary.json
#   -> Processing 22RS0052: Тогульский районный суд (Алтайский край)
#      website=http://togulsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0052/court_summary.json
#   -> Processing 22RS0053: Топчихинский районный суд (Алтайский край)
#      website=http://topchihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0053/court_summary.json
#   -> Processing 22RS0054: Третьяковский районный суд (Алтайский край)
#      website=http://tretiakovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0054/court_summary.json
#   -> Processing 22RS0055: Троицкий районный суд (Алтайский край)
#      website=http://troicky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0055/court_summary.json
#   -> Processing 22RS0056: Тюменцевский районный суд (Алтайский край)
#      website=http://tumencevsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0056/court_summary.json
#   -> Processing 22RS0057: Угловский районный суд (Алтайский край)
#      website=http://uglovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0057/court_summary.json
#   -> Processing 22RS0058: Усть-Калманский районный суд (Алтайский край)
#      website=http://ukalmansky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0058/court_summary.json
#   -> Processing 22RS0059: Усть-Пристанский районный суд (Алтайский край)
#      website=http://upristansky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0059/court_summary.json
#   -> Processing 22RS0060: Хабарский районный суд (Алтайский край)
#      website=http://habarsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0060/court_summary.json
#   -> Processing 22RS0061: Целинный районный суд (Алтайский край)
#      website=http://celinniy.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0061/court_summary.json
#   -> Processing 22RS0068: Центральный районный суд г. Барнаула (Алтайский край)
#      website=http://centralny.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0068/court_summary.json
#   -> Processing 22RS0062: Чарышский районный суд (Алтайский край)
#      website=http://charishsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0062/court_summary.json
#   -> Processing 22RS0063: Шелаболихинский районный суд (Алтайский край)
#      website=http://shelabolihinsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0063/court_summary.json
#   -> Processing 22RS0064: Шипуновский районный суд (Алтайский край)
#      website=http://shipunovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0064/court_summary.json
#   -> Processing 22RS0071: Яровской районный суд (Алтайский край)
#      website=http://yarovsky.alt.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/22/22RS0071/court_summary.json
#
# === Region 28 ===
#   -> Processing 28OS0000: Амурский областной суд (Амурская область)
#      website=http://oblsud.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28OS0000/court_summary.json
#   -> Processing 28RS0001: Архаринский районный суд (Амурская область)
#      website=http://arharinskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0001/court_summary.json
#   -> Processing 27GV0005: Белогорский гарнизонный военный суд (Амурская область)
#      website=http://belgvs.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/27GV0005/court_summary.json
#   -> Processing 28RS0002: Белогорский городской суд (Амурская область)
#      website=http://belogorskiygs.amr.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0002/court_summary.json
#   -> Processing 27GV0006: Благовещенский гарнизонный военный суд (Амурская область)
#      website=http://bgvs.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/27GV0006/court_summary.json
#   -> Processing 28RS0004: Благовещенский городской суд (Амурская область)
#      website=http://blag-gs.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0004/court_summary.json
#   -> Processing 28RS0005: Благовещенский районный суд (Амурская область)
#      website=http://blag-rs.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0005/court_summary.json
#   -> Processing 28RS0006: Бурейский районный суд (Амурская область)
#      website=http://bureiskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0006/court_summary.json
#   -> Processing 28RS0007: Завитинский районный суд (Амурская область)
#      website=http://zavitnskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0007/court_summary.json
#   -> Processing 28RS0008: Зейский районный суд (Амурская область)
#      website=http://zeiskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0008/court_summary.json
#   -> Processing 28RS0009: Ивановский районный суд (Амурская область)
#      website=http://ivanovskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0009/court_summary.json
#   -> Processing 28RS0010: Константиновский районный суд (Амурская область)
#      website=http://konstantin.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0010/court_summary.json
#   -> Processing 28RS0012: Магдагачинский районный суд (Амурская область)
#      website=http://magdagachinskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0012/court_summary.json
#   -> Processing 28RS0011: Мазановский районный суд (Амурская область)
#      website=http://mazanovskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0011/court_summary.json
#   -> Processing 28RS0013: Михайловский районный суд (Амурская область)
#      website=http://mihailovskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0013/court_summary.json
#   -> Processing 28RS0014: Октябрьский районный суд (Амурская область)
#      website=http://oktyabrsiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0014/court_summary.json
#   -> Processing 28RS0015: Райчихинский городской суд (Амурская область)
#      website=http://raichihinskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0015/court_summary.json
#   -> Processing 28RS0016: Ромненский районный суд (Амурская область)
#      website=http://romnenskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0016/court_summary.json
#   -> Processing 27GV0003: Свободненский гарнизонный военный суд (Амурская область)
#      website=http://sgvs.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/27GV0003/court_summary.json
#   -> Processing 28RS0017: Свободненский городской суд (Амурская область)
#      website=http://svobodnenskgs.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0017/court_summary.json
#   -> Processing 28RS0020: Селемджинский районный суд (Амурская область)
#      website=http://selemdginskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0020/court_summary.json
#   -> Processing 28RS0019: Серышевский районный суд (Амурская область)
#      website=http://serishevskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0019/court_summary.json
#   -> Processing 28RS0021: Сковородинский районный суд (Амурская область)
#      website=http://skovorodinskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0021/court_summary.json
#   -> Processing 28RS0022: Тамбовский районный суд (Амурская область)
#      website=http://tambovskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0022/court_summary.json
#   -> Processing 28RS0023: Тындинский районный суд (Амурская область)
#      website=http://tindinskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0023/court_summary.json
#   -> Processing 28RS0024: Шимановский районный суд (Амурская область)
#      website=http://shimanovskiy.amr.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/28/28RS0024/court_summary.json
#
# === Region 29 ===
#   -> Processing 78GV0002: Архангельский гарнизонный военный суд (Архангельская область)
#      website=http://agvs.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/78GV0002/court_summary.json
#   -> Processing 29OS0000: Архангельский областной суд (Архангельская область)
#      website=http://oblsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29OS0000/court_summary.json
#   -> Processing 29RS0001: Вельский районный суд (Архангельская область)
#      website=http://velsksud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0001/court_summary.json
#   -> Processing 29RS0003: Вилегодский районный суд (Архангельская область)
#      website=http://vilegsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0003/court_summary.json
#   -> Processing 29RS0004: Виноградовский районный суд (Архангельская область)
#      website=http://vinogsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0004/court_summary.json
#   -> Processing 29RS0005: Исакогорский районный суд г. Архангельска (Архангельская область)
#      website=http://sudis.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0005/court_summary.json
#   -> Processing 29RS0007: Коношский районный суд (Архангельская область)
#      website=http://konoshasud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0007/court_summary.json
#   -> Processing 29RS0010: Коряжемский городской суд (Архангельская область)
#      website=http://koryazhmasud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0010/court_summary.json
#   -> Processing 29RS0008: Котласский городской суд (Архангельская область)
#      website=http://kotlasgrsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0008/court_summary.json
#   -> Processing 29RS0011: Красноборский районный суд (Архангельская область)
#      website=http://krasnsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0011/court_summary.json
#   -> Processing 29RS0013: Лешуконский районный суд (Архангельская область)
#      website=http://leshksud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0013/court_summary.json
#   -> Processing 29RS0014: Ломоносовский районный суд г. Архангельска (Архангельская область)
#      website=http://lomonosovsky.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0014/court_summary.json
#   -> Processing 31GV0008: Мирненский гарнизонный военный суд (Архангельская область)
#      website=http://vmgvs.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/31GV0008/court_summary.json
#   -> Processing 29RS0028: Мирнинский городской суд (Архангельская область)
#      website=http://mirnsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0028/court_summary.json
#   -> Processing 29RS0016: Новодвинский городской суд (Архангельская область)
#      website=http://novodvdsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0016/court_summary.json
#   -> Processing 29RS0017: Няндомский районный суд (Архангельская область)
#      website=http://nyandomasud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0017/court_summary.json
#   -> Processing 29RS0018: Октябрьский районный суд г. Архангельска (Архангельская область)
#      website=http://oktsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0018/court_summary.json
#   -> Processing 29RS0019: Онежский городской суд (Архангельская область)
#      website=http://onegasud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0019/court_summary.json
#   -> Processing 29RS0020: Пинежский районный суд (Архангельская область)
#      website=http://pinegasud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0020/court_summary.json
#   -> Processing 29RS0021: Плесецкий районный суд (Архангельская область)
#      website=http://pleseck.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0021/court_summary.json
#   -> Processing 29RS0022: Приморский районный суд (Архангельская область)
#      website=http://primsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0022/court_summary.json
#   -> Processing 51GV0002: Северодвинский гарнизонный военный суд (Архангельская область)
#      website=http://sgvs.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/51GV0002/court_summary.json
#   -> Processing 29RS0023: Северодвинский городской суд (Архангельская область)
#      website=http://seversud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0023/court_summary.json
#   -> Processing 29RS0024: Соломбальский районный суд г. Архангельска (Архангельская область)
#      website=http://solombsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0024/court_summary.json
#   -> Processing 29RS0025: Устьянский районный суд (Архангельская область)
#      website=http://ustyansud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0025/court_summary.json
#   -> Processing 29RS0026: Холмогорский районный суд (Архангельская область)
#      website=http://holmsud.arh.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/29/29RS0026/court_summary.json
#
# === Region 30 ===
#   -> Processing 61GV0003: Астраханский гарнизонный военный суд (Астраханская область)
#      website=http://astrahanskygvs.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/61GV0003/court_summary.json
#   -> Processing 30OS0000: Астраханский областной суд (Астраханская область)
#      website=http://oblsud.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30OS0000/court_summary.json
#   -> Processing 30RS0005: Ахтубинский районный суд (Астраханская область)
#      website=http://ahtubinsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0005/court_summary.json
#   -> Processing 30RS0006: Володарский районный суд (Астраханская область)
#      website=http://volodarsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0006/court_summary.json
#   -> Processing 30RS0007: Енотаевский районный суд (Астраханская область)
#      website=http://enotaevsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0007/court_summary.json
#   -> Processing 31GV0007: Знаменский гарнизонный военный суд (Астраханская область)
#      website=http://znamenskygvs.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/31GV0007/court_summary.json
#   -> Processing 30RS0008: Икрянинский районный суд (Астраханская область)
#      website=http://ikryaninsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0008/court_summary.json
#   -> Processing 30RS0009: Камызякский районный суд (Астраханская область)
#      website=http://kamizyaksky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0009/court_summary.json
#   -> Processing 30RS0001: Кировский районный суд г. Астрахани (Астраханская область)
#      website=http://kirovsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0001/court_summary.json
#   -> Processing 30RS0010: Красноярский районный суд (Астраханская область)
#      website=http://krasnoyarsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0010/court_summary.json
#   -> Processing 30RS0002: Ленинский районный суд г. Астрахани (Астраханская область)
#      website=http://leninsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0002/court_summary.json
#   -> Processing 30RS0011: Лиманский районный суд (Астраханская область)
#      website=http://limansky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0011/court_summary.json
#   -> Processing 30RS0012: Наримановский районный суд (Астраханская область)
#      website=http://narimanovsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0012/court_summary.json
#   -> Processing 30RS0013: Приволжский районный суд (Астраханская область)
#      website=http://privolzhsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0013/court_summary.json
#   -> Processing 30RS0003: Советский районный суд г. Астрахани (Астраханская область)
#      website=http://sovetsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0003/court_summary.json
#   -> Processing 30RS0004: Трусовский районный суд г. Астрахани (Астраханская область)
#      website=http://trusovsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0004/court_summary.json
#   -> Processing 30RS0014: Харабалинский районный суд (Астраханская область)
#      website=http://harabalinsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0014/court_summary.json
#   -> Processing 30RS0015: Черноярский районный суд (Астраханская область)
#      website=http://chernoyarsky.ast.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/30/30RS0015/court_summary.json
#
# === Region 31 ===
#   -> Processing 31RS0001: Алексеевский районный суд (Белгородская область)
#      website=http://alekseevsky.blg.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0001/court_summary.json
#   -> Processing 31OS0000: Белгородский областной суд (Белгородская область)
#      website=http://oblsud.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31OS0000/court_summary.json
#   -> Processing 31RS0002: Белгородский районный суд (Белгородская область)
#      website=http://belgorodsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0002/court_summary.json
#   -> Processing 31RS0003: Борисовский районный суд (Белгородская область)
#      website=http://borisovsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0003/court_summary.json
#   -> Processing 31RS0004: Валуйский районный суд (Белгородская область)
#      website=http://valuisky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0004/court_summary.json
#   -> Processing 31RS0005: Вейделевский районный суд (Белгородская область)
#      website=http://veidelevsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0005/court_summary.json
#   -> Processing 31RS0006: Волоконовский районный суд (Белгородская область)
#      website=http://volokonovsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0006/court_summary.json
#   -> Processing 31RS0009: Грайворонский районный суд (Белгородская область)
#      website=http://graivoronsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0009/court_summary.json
#   -> Processing 31RS0007: Губкинский городской суд (Белгородская область)
#      website=http://gubkinskygor.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0007/court_summary.json
#   -> Processing 31RS0010: Ивнянский районный суд (Белгородская область)
#      website=http://ivniansky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0010/court_summary.json
#   -> Processing 31RS0011: Корочанский районный суд (Белгородская область)
#      website=http://korochansky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0011/court_summary.json
#   -> Processing 31RS0012: Красногвардейский районный суд (Белгородская область)
#      website=http://krasnogvardeisky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0012/court_summary.json
#   -> Processing 31RS0015: Новооскольский районный суд (Белгородская область)
#      website=http://novooskolsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0015/court_summary.json
#   -> Processing 31RS0016: Октябрьский районный суд г. Белгорода (Белгородская область)
#      website=http://oktiabrsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0016/court_summary.json
#   -> Processing 31RS0017: Прохоровский районный суд (Белгородская область)
#      website=http://prohorovsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0017/court_summary.json
#   -> Processing 31RS0018: Ракитянский районный суд (Белгородская область)
#      website=http://rakitiansky.blg.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0018/court_summary.json
#   -> Processing 31RS0019: Ровеньский районный суд (Белгородская область)
#      website=http://rovensky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0019/court_summary.json
#   -> Processing 31RS0022: Свердловский районный суд г. Белгорода (Белгородская область)
#      website=http://sverdlovsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0022/court_summary.json
#   -> Processing 31RS0020: Старооскольский городской суд (Белгородская область)
#      website=http://starooskolskygor.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0020/court_summary.json
#   -> Processing 31RS0021: Старооскольский районный суд (Белгородская область)
#      website=http://starooskolsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0021/court_summary.json
#   -> Processing 31RS0023: Чернянский районный суд (Белгородская область)
#      website=http://cherniansky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0023/court_summary.json
#   -> Processing 31RS0024: Шебекинский районный суд (Белгородская область)
#      website=http://shebekinsky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0024/court_summary.json
#   -> Processing 31RS0025: Яковлевский районный суд (Белгородская область)
#      website=http://yakovlensky.blg.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/31/31RS0025/court_summary.json
#
# === Region 32 ===
#   -> Processing 32RS0001: Бежицкий районный суд г. Брянска (Брянская область)
#      website=http://bezhitsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0001/court_summary.json
#   -> Processing 32RS0002: Брасовский районный суд (Брянская область)
#      website=http://brasovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0002/court_summary.json
#   -> Processing 77GV0018: Брянский гарнизонный военный суд (Брянская область)
#      website=http://gvs.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/77GV0018/court_summary.json
#   -> Processing 32OS0000: Брянский областной суд (Брянская область)
#      website=http://oblsud.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32OS0000/court_summary.json
#   -> Processing 32RS0003: Брянский районный суд (Брянская область)
#      website=http://briansky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0003/court_summary.json
#   -> Processing 32RS0004: Володарский районный суд г. Брянска (Брянская область)
#      website=http://volodarsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0004/court_summary.json
#   -> Processing 32RS0005: Выгоничский районный суд (Брянская область)
#      website=http://vigonichsky.brj.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0005/court_summary.json
#   -> Processing 32RS0007: Дубровский районный суд (Брянская область)
#      website=http://dubrovsky.brj.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0007/court_summary.json
#   -> Processing 32RS0008: Дятьковский городской суд (Брянская область)
#      website=http://diatkovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0008/court_summary.json
#   -> Processing 32RS0010: Жуковский районный суд (Брянская область)
#      website=http://zhukovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0010/court_summary.json
#   -> Processing 32RS0011: Злынковский районный суд (Брянская область)
#      website=http://zlinkovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0011/court_summary.json
#   -> Processing 32RS0012: Карачевский районный суд (Брянская область)
#      website=http://karachevsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0012/court_summary.json
#   -> Processing 32RS0013: Клетнянский районный суд (Брянская область)
#      website=http://kletniansky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0013/court_summary.json
#   -> Processing 32RS0014: Климовский районный суд (Брянская область)
#      website=http://klimovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0014/court_summary.json
#   -> Processing 32RS0015: Клинцовский городской суд (Брянская область)
#      website=http://klyncovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0015/court_summary.json
#   -> Processing 32RS0016: Клинцовский районный суд (Брянская область)
#      website=http://klincovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0016/court_summary.json
#   -> Processing 32RS0017: Комаричский районный суд (Брянская область)
#      website=http://komarichsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0017/court_summary.json
#   -> Processing 32RS0018: Красногорский районный суд (Брянская область)
#      website=http://krasnogorsky.brj.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0018/court_summary.json
#   -> Processing 32RS0019: Мглинский районный суд (Брянская область)
#      website=http://mglinsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0019/court_summary.json
#   -> Processing 32RS0020: Навлинский районный суд (Брянская область)
#      website=http://navlinsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0020/court_summary.json
#   -> Processing 32RS0021: Новозыбковский городской суд (Брянская область)
#      website=http://novozibkovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0021/court_summary.json
#   -> Processing 32RS0022: Погарский районный суд (Брянская область)
#      website=http://pogarsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0022/court_summary.json
#   -> Processing 32RS0023: Почепский районный суд (Брянская область)
#      website=http://pochepsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0023/court_summary.json
#   -> Processing 32RS0025: Севский районный суд (Брянская область)
#      website=http://sevsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0025/court_summary.json
#   -> Processing 32RS0026: Сельцовский городской суд (Брянская область)
#      website=http://selcovsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0026/court_summary.json
#   -> Processing 32RS0027: Советский районный суд г. Брянска (Брянская область)
#      website=http://sovetsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0027/court_summary.json
#   -> Processing 32RS0028: Стародубский районный суд (Брянская область)
#      website=http://starodubsky.brj.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/32/32RS0028/court_summary.json
# ...
#   -> Processing 43RS0020: Лузский районный суд (Кировская область)
#      website=http://luzsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0020/court_summary.json
#   -> Processing 43RS0021: Малмыжский районный суд (Кировская область)
#      website=http://malmizhsky.kir.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0021/court_summary.json
#   -> Processing 43RS0022: Мурашинский районный суд (Кировская область)
#      website=http://murashinsky.kir.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0022/court_summary.json
#   -> Processing 43RS0004: Нововятский районный суд г. Кирова (Кировская область)
#      website=http://novovyatsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0004/court_summary.json
#   -> Processing 43RS0025: Нолинский районный суд (Кировская область)
#      website=http://nolinsky.kir.sudrf.ru, srv=['1', '2', '3']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0025/court_summary.json
#   -> Processing 43RS0002: Октябрьский районный суд г. Кирова (Кировская область)
#      website=http://oktyabrsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0002/court_summary.json
#   -> Processing 43RS0026: Омутнинский районный суд (Кировская область)
#      website=http://omutninsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0026/court_summary.json
#   -> Processing 43RS0028: Оричевский районный суд (Кировская область)
#      website=http://orichevsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0028/court_summary.json
#   -> Processing 43RS0003: Первомайский районный суд г. Кирова (Кировская область)
#      website=http://pervomaysky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0003/court_summary.json
#   -> Processing 43RS0031: Подосиновский районный суд (Кировская область)
#      website=http://podosinovsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0031/court_summary.json
#   -> Processing 43RS0032: Санчурский районный суд (Кировская область)
#      website=http://sanchursky.kir.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0032/court_summary.json
#   -> Processing 43RS0034: Слободской районный суд (Кировская область)
#      website=http://slobodskoy.kir.sudrf.ru, srv=['1', '2', '3']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0034/court_summary.json
#   -> Processing 43RS0035: Советский районный суд (Кировская область)
#      website=http://sovetsky.kir.sudrf.ru, srv=['1', '2', '3', '4']
#      ✖ ERROR for 43RS0035: Message: invalid session id
#
#      ✔ Saved error log → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0035/error.json
#   -> Processing 43RS0038: Унинский районный суд (Кировская область)
#      website=http://uninsky.kir.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0038/court_summary.json
#   -> Processing 43RS0039: Уржумский районный суд (Кировская область)
#      website=http://urzhumsky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0039/court_summary.json
#   -> Processing 43RS0041: Шабалинский районный суд (Кировская область)
#      website=http://shabalinsky.kir.sudrf.ru, srv=['1', '2']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0041/court_summary.json
#   -> Processing 43RS0042: Юрьянский районный суд (Кировская область)
#      website=http://yuryansky.kir.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0042/court_summary.json
#   -> Processing 43RS0043: Яранский районный суд (Кировская область)
#      website=http://yaransky.kir.sudrf.ru, srv=['1', '2', '3']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/43/43RS0043/court_summary.json
#
# === Region 44 ===
#   -> Processing 44RS0005: Буйский районный суд (Костромская область)
#      website=http://buisky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0005/court_summary.json
#   -> Processing 44RS0015: Вохомский районный суд (Костромская область)
#      website=http://vohomsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0015/court_summary.json
#   -> Processing 44RS0006: Галичский районный суд (Костромская область)
#      website=http://galichsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0006/court_summary.json
#   -> Processing 44RS0026: Димитровский районный суд г. Костромы (Костромская область)
#      website=http://dimitrovsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0026/court_summary.json
#   -> Processing 44RS0024: Кологривский районный суд (Костромская область)
#      website=http://kologrivsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0024/court_summary.json
#   -> Processing 44OS0000: Костромской областной суд (Костромская область)
#      website=http://oblsud.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44OS0000/court_summary.json
#   -> Processing 44RS0028: Костромской районный суд (Костромская область)
#      website=http://kostromskoy.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0028/court_summary.json
#   -> Processing 44RS0013: Красносельский районный суд (Костромская область)
#      website=http://krasnoselsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0013/court_summary.json
#   -> Processing 44RS0002: Ленинский районный суд г. Костромы (Костромская область)
#      website=http://leninsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0002/court_summary.json
#   -> Processing 44RS0023: Макарьевский районный суд (Костромская область)
#      website=http://makarievsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0023/court_summary.json
#   -> Processing 44RS0004: Мантуровский районный суд (Костромская область)
#      website=http://manturovsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0004/court_summary.json
#   -> Processing 44RS0011: Нейский районный суд (Костромская область)
#      website=http://neisky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0011/court_summary.json
#   -> Processing 44RS0027: Нерехтский районный суд (Костромская область)
#      website=http://nerehtsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0027/court_summary.json
#   -> Processing 44RS0014: Островский районный суд (Костромская область)
#      website=http://ostrovsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0014/court_summary.json
#   -> Processing 44RS0009: Павинский районный суд (Костромская область)
#      website=http://pavinsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0009/court_summary.json
#   -> Processing 44RS0001: Свердловский районный суд г. Костромы (Костромская область)
#      website=http://sverdlovsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0001/court_summary.json
#   -> Processing 44RS0019: Чухломский районный суд (Костромская область)
#      website=http://chuhlomsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0019/court_summary.json
#   -> Processing 44RS0003: Шарьинский районный суд (Костромская область)
#      website=http://sharinsky.kst.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/44/44RS0003/court_summary.json
#
# === Region 23 ===
#   -> Processing 23RS0001: Абинский районный суд (Краснодарский край)
#      website=http://abinsk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0001/court_summary.json
#   -> Processing 23RS0002: Адлерский районный суд г. Сочи (Краснодарский край)
#      website=http://sochi-adler.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0002/court_summary.json
#   -> Processing 23RS0003: Анапский городской суд (Краснодарский край)
#      website=http://anapa-gor.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0003/court_summary.json
#   -> Processing 23RS0004: Анапский районный суд (Краснодарский край)
#      website=http://anapa.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0004/court_summary.json
#   -> Processing 23RS0005: Апшеронский районный суд (Краснодарский край)
#      website=http://apsheronsk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0005/court_summary.json
#   -> Processing 23RS0006: Армавирский городской суд (Краснодарский край)
#      website=http://armavir.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0006/court_summary.json
#   -> Processing 23RS0007: Белоглинский районный суд (Краснодарский край)
#      website=http://beloglinsk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0007/court_summary.json
#   -> Processing 23RS0008: Белореченский районный суд (Краснодарский край)
#      website=http://belorechensk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0008/court_summary.json
#   -> Processing 23RS0009: Брюховецкий районный суд (Краснодарский край)
#      website=http://bruxovecky.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0009/court_summary.json
#   -> Processing 23RS0010: Выселковский районный суд (Краснодарский край)
#      website=http://viselkovsky.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0010/court_summary.json
#   -> Processing 23RS0011: Геленджикский городской суд (Краснодарский край)
#      website=http://gelendjik-gor.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0011/court_summary.json
#   -> Processing 23RS0012: Горячеключевской городской суд (Краснодарский край)
#      website=http://gor-kluch.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0012/court_summary.json
#   -> Processing 23RS0013: Гулькевичский районный суд (Краснодарский край)
#      website=http://gulkevichi.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0013/court_summary.json
#   -> Processing 23RS0014: Динской районный суд (Краснодарский край)
#      website=http://dinskoy.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0014/court_summary.json
#   -> Processing 23RS0015: Ейский городской суд (Краснодарский край)
#      website=http://eisk-gor.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0015/court_summary.json
#   -> Processing 23RS0016: Ейский районный суд (Краснодарский край)
#      website=http://eisk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0016/court_summary.json
#   -> Processing 23RS0017: Кавказский районный суд (Краснодарский край)
#      website=http://kavkazsky.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0017/court_summary.json
#   -> Processing 23RS0018: Калининский районный суд (Краснодарский край)
#      website=http://kalininsk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0018/court_summary.json
#   -> Processing 23RS0019: Каневской районный суд (Краснодарский край)
#      website=http://kanevskay.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0019/court_summary.json
#   -> Processing 23RS0020: Кореновский районный суд (Краснодарский край)
#      website=http://korenovsk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0020/court_summary.json
#   -> Processing 23RS0021: Красноармейский районный суд (Краснодарский край)
#      website=http://krasnoarmeisk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0021/court_summary.json
#   -> Processing 61GV0004: Краснодарский гарнизонный военный суд (Краснодарский край)
#      website=http://gvs.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/61GV0004/court_summary.json
#   -> Processing 23OS0000: Краснодарский краевой суд (Краснодарский край)
#      website=http://kraevoi.krd.sudrf.ru, srv=['1']
# Autorecognition of captcha failed. Enter captcha manually
# Enter captcha:  ерс97
#      ✖ ERROR for 23OS0000: Message: invalid session id
#
#      ✔ Saved error log → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23OS0000/error.json
#   -> Processing 23RS0022: Кропоткинский городской суд (Краснодарский край)
#      website=http://kropotkin-gor.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0022/court_summary.json
#   -> Processing 23RS0023: Крыловской районный суд (Краснодарский край)
#      website=http://krilovskoy.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0023/court_summary.json
#   -> Processing 23RS0024: Крымский районный суд (Краснодарский край)
#      website=http://krimsk.krd.sudrf.ru, srv=['1']
#      ✔ Saved summary → /Users/ana/Projects/soas/russian courts/sudrf_results_run_18.12_6_21/23/23RS0024/court_summary.json
#   -> Processing 23RS0025: Курганинский районный суд (Краснодарский край)
#      website=http://kurganinsk.krd.sudrf.ru, srv=['1']
